# %%
import torch
import torchvision
import timm
print('torch:', torch.__version__)
print('torchvision:', torchvision.__version__)
print('timm:', timm.__version__)
print('CUDA disponible:', torch.cuda.is_available())
# Out:
# torch: 2.12.0.dev20260407+cu128
# torchvision: 0.27.0.dev20260407+cu128
# timm: 0.6.7
# CUDA disponible: True

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['song_id', 'instrument', 'source_format', 'tokens', 'num_tokens', 'num_beats', 'mert_embeddings', 'logmel_frames', 'beat_times_s', 'beat_durations_s', 'bpm_at_beat', 'time_sig_num_at_beat', 'time_sig_den_at_beat', 'song_name', 'artist', 'genre', 'charter', 'year', 'song_length_ms', 'difficulty', 'resolution', 'has_star_power', 'has_solo', 'has_dedicated_stem', 'num_notes', 'notes_per_beat_mean', 'chord_ratio', 'sustain_mean_ticks', 'bpm_mean', 'bpm_std'],
#         num_rows: 43665
#     })
# })

# %%
from datasets import load_dataset

# Descarga directamente a una carpeta específica
ds = load_dataset(
    "thejorseman/CloneHeroDatasetCharts",
    cache_dir="/s/mlopezs8/CloneCharter/cache"
)
# Out:
# Resolving data files:   0%|          | 0/1753 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/878 [00:00<?, ?it/s]

# %%
ds.save_to_disk("/s/mlopezs8/CloneCharter/dataset")
# Out:
# Saving the dataset (0/1025 shards):   0%|          | 0/43665 [00:00<?, ? examples/s]

# %%
# !chmod +x train.sh

# %%
# !./find_max_bath.sh
# Out:
# GPU:  NVIDIA H100 80GB HBM3  (79.2 GB VRAM)
# Sequence: 2048 tokens × 256 beats  |  precision: bf16
# Model: 6,268,545 parameters
#
# Searching  bs=128 OK  bs=192 OK  bs=224 OK  bs=240 OK  bs=248 OK  bs=252 OK  bs=254 OK  bs=255 OK  bs=256 OK
#
# Max batch size: 256
# Recommended --batch-size for training (with some headroom): 204

# %%
# !./train.sh
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# Loading dataset in streaming mode from: dataset/train
#   → No parquet shards found; detected 1025 Arrow shards
# ShardIndexedDataset: 1000 train | 25 val shards
#   Val: 1061 rows in RAM (no Arrow conversion)
# Building shard manifest from 1000 shards (reading row counts only)...
#   scanned 200/1000 shards — 8517 rows indexed
#   scanned 400/1000 shards — 17049 rows indexed
#   scanned 600/1000 shards — 25573 rows indexed
#   scanned 800/1000 shards — 34091 rows indexed
#   scanned 1000/1000 shards — 42604 rows indexed
#   [manifest cache] saved to dataset/train/.shard_manifest_cache.json
# Manifest ready: 42604 rows across 1000 shards
# ShardIndexed | 42604 train rows | 1061 val rows | max 1 shards in RAM
# Model parameters: 8,038,017
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776682788.711551    1547 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1776682788.748930    1547 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776682789.922857    1547 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Training AutoCharterModel (8,038,017 parameters)
# Train batches: 2663, Val batches: 133
# Epoch 0:   1%|▏        | 38/2663 [00:45<42:45,  1.02it/s, loss=91.2519, step=19]^C
